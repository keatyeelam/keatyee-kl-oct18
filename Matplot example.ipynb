# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4,5])
plt.ylabel('Some significant numbers')
plt.show()

# %% [markdown]
# integrated with numpy

# %%
t = np.arange(0.,5.,0.2)

# %%
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.axis([0,6,0,150]) #x and y axis range
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# %% [markdown]
# # the histogram of the data

# %%
n, bins, patches = plt.hist(x,50,normed=1,facecolor='g',alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$') #TeX equations
plt.axis([40,160,0,0.03])
plt.grid(True)
plt.show()
# Out:
# /Users/lamkeatyee/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
